# %%
import pandas as pd
Titanic=pd.read_csv("titanic-passengers.csv",delimiter=";")
Titanic.tail(50)
# Out:
#      PassengerId Survived  Pclass  \
# 841          513      Yes       1
# 842          113       No       3
# 843           16      Yes       2
# 844          193      Yes       3
# 845          297       No       3
# 846          834       No       3
# 847          888      Yes       1
# 848          822      Yes       3
# 849           92       No       3
# 850          236       No       3
# 851          757       No       3
# 852          673       No       2
# 853          585       No       3
# 854            1       No       3
# 855          264       No       1
# 856          184      Yes       2
# 857          514      Yes       1
# 858          304      Yes       2
# 859          552       No       2
# 860          206       No       3
# 861          868       No       1
# 862          619      Yes       2
# 863          858      Yes       1
# 864          179       No       2
# 865          196      Yes       1
# 866          558       No       1
# 867          737       No       3
# 868          602       No       3
# 869           46       No       3
# 870          520       No       3
# 871          812       No       3
# 872          786       No       3
# 873           43       No       3
# 874           60       No       3
# 875          463       No       1
# 876          375       No       3
# 877          271       No       1
# 878          787      Yes       3
# 879          275      Yes       3
# 880          360      Yes       3
# 881          699       No       1
# 882          775      Yes       2
# 883          809       No       2
# 884          278       No       2
# 885          150       No       2
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 841                          McGough, Mr. James Robert    male  36.0      0
# 842                             Barton, Mr. David John    male  22.0      0
# 843                    Hewlett, Mrs. (Mary D Kingcome)  female  55.0      0
# 844    Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0      1
# 845                                 Hanna, Mr. Mansour    male  23.5      0
# 846                             Augustsson, Mr. Albert    male  23.0      0
# 847                       Graham, Miss. Margaret Edith  female  19.0      0
# 848                                  Lulic, Mr. Nikola    male  27.0      0
# 849                         Andreasson, Mr. Paul Edvin    male  20.0      0
# 850                       Harknett, Miss. Alice Phoebe  female   NaN      0
# 851                       Carlsson, Mr. August Sigfrid    male  28.0      0
# 852                        Mitchell, Mr. Henry Michael    male  70.0      0
# 853                                Paulner, Mr. Uscher    male   NaN      0
# 854                            Braund, Mr. Owen Harris    male  22.0      1
# 855                              Harrison, Mr. William    male  40.0      0
# 856                          Becker, Master. Richard F    male   1.0      2
# 857     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 858                                Keane, Miss. Nora A  female   NaN      0
# 859                        Sharp, Mr. Percival James R    male  27.0      0
# 860                         Strom, Miss. Telma Matilda  female   2.0      0
# 861               Roebling, Mr. Washington Augustus II    male  31.0      0
# 862                        Becker, Miss. Marion Louise  female   4.0      2
# 863                              Daly, Mr. Peter Denis    male  51.0      0
# 864                                 Hale, Mr. Reginald    male  30.0      0
# 865                               Lurette, Miss. Elise  female  58.0      0
# 866                                Robbins, Mr. Victor    male   NaN      0
# 867            Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0      1
# 868                               Slabenoff, Mr. Petco    male   NaN      0
# 869                           Rogers, Mr. William John    male   NaN      0
# 870                                Pavlovic, Mr. Stefo    male  32.0      0
# 871                                  Lester, Mr. James    male  39.0      0
# 872                 Harmer, Mr. Abraham (David Lishin)    male  25.0      0
# 873                                Kraeff, Mr. Theodor    male   NaN      0
# 874                 Goodwin, Master. William Frederick    male  11.0      5
# 875                                  Gee, Mr. Arthur H    male  47.0      0
# 876                         Palsson, Miss. Stina Viola  female   3.0      3
# 877                              Cairns, Mr. Alexander    male   NaN      0
# 878                          Sjoblom, Miss. Anna Sofia  female  18.0      0
# 879                         Healy, Miss. Hanora "Nora"  female   NaN      0
# 880                  Mockler, Miss. Helen Mary "Ellie"  female   NaN      0
# 881                           Thayer, Mr. John Borland    male  49.0      1
# 882              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1
# 883                                  Meyer, Mr. August    male  39.0      0
# 884                        Parkes, Mr. Francis "Frank"    male   NaN      0
# 885                  Byles, Rev. Thomas Roussel Davids    male  42.0      0
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch           Ticket      Fare Cabin Embarked
# 841      0         PC 17473   26.2875   E25        S
# 842      0           324669    8.0500   NaN        S
# 843      0           248706   16.0000   NaN        S
# 844      0           350046    7.8542   NaN        S
# 845      0             2693    7.2292   NaN        C
# 846      0           347468    7.8542   NaN        S
# 847      0           112053   30.0000   B42        S
# 848      0           315098    8.6625   NaN        S
# 849      0           347466    7.8542   NaN        S
# 850      0       W./C. 6609    7.5500   NaN        S
# 851      0           350042    7.7958   NaN        S
# 852      0       C.A. 24580   10.5000   NaN        S
# 853      0             3411    8.7125   NaN        C
# 854      0        A/5 21171    7.2500   NaN        S
# 855      0           112059    0.0000   B94        S
# 856      1           230136   39.0000    F4        S
# 857      0         PC 17603   59.4000   NaN        C
# 858      0           226593   12.3500  E101        Q
# 859      0           244358   26.0000   NaN        S
# 860      1           347054   10.4625    G6        S
# 861      0         PC 17590   50.4958   A24        S
# 862      1           230136   39.0000    F4        S
# 863      0           113055   26.5500   E17        S
# 864      0           250653   13.0000   NaN        S
# 865      0         PC 17569  146.5208   B80        C
# 866      0         PC 17757  227.5250   NaN        C
# 867      3       W./C. 6608   34.3750   NaN        S
# 868      0           349214    7.8958   NaN        S
# 869      0  S.C./A.4. 23567    8.0500   NaN        S
# 870      0           349242    7.8958   NaN        S
# 871      0        A/4 48871   24.1500   NaN        S
# 872      0           374887    7.2500   NaN        S
# 873      0           349253    7.8958   NaN        C
# 874      2          CA 2144   46.9000   NaN        S
# 875      0           111320   38.5000   E63        S
# 876      1           349909   21.0750   NaN        S
# 877      0           113798   31.0000   NaN        S
# 878      0          3101265    7.4958   NaN        S
# 879      0           370375    7.7500   NaN        Q
# 880      0           330980    7.8792   NaN        Q
# 881      1            17421  110.8833   C68        C
# 882      3            29105   23.0000   NaN        S
# 883      0           248723   13.0000   NaN        S
# 884      0           239853    0.0000   NaN        S
# 885      0           244310   13.0000   NaN        S
# 886      0           237736   30.0708   NaN        C
# 887      0             2669    7.2292   NaN        C
# 888      0           315084    8.6625   NaN        S
# 889      0           349215    7.8958   NaN        S
# 890      0           250655   26.0000   NaN        S

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
#Missing Values
Titanic.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False   True     False
# 4    False  False     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False   True     False
# 888  False   True     False
# 889  False   True     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
#Number of missing values by features
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Total number of missing values 
Titanic.isnull().sum().sum()
# Out:
# 866

# %%
#Delite Feature 'Cabin'
Titanic.dropna(axis=1,how='any',thresh=687,inplace=True)
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
#Replace all Nan of feature 'Age'by the mean

Titanic.fillna(Titanic['Age'].mean(), inplace=True)
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
#Histogram Seaborn
import seaborn as sns
sns.distplot(Titanic['Age'],bins=10,hist=True,kde=True,color='red')

# %%
#Barplot (used on categorical data)
import matplotlib.pyplot as plt
sns.countplot(x='Sex',data=Titanic)
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
sns.countplot(x='Survived',data=Titanic)
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
#correlation between Survived and Sex
g=sns.FacetGrid(Titanic,col='Sex')
g.map(plt.hist,'Survived',bins=10)

# %%
#correlation between Sex and Age
g=sns.FacetGrid(Titanic,col='Sex')
g.map(plt.hist,'Age',bins=10)

# %%
plt.scatter(Titanic.Age,Titanic.Sex)

# %%
from sklearn.preprocessing import LabelEncoder
Titanic['Pclass']=LabelEncoder().fit_transform(Titanic['Pclass'])
Titanic['Survived']=LabelEncoder().fit_transform(Titanic['Survived'])
Titanic['Sex']=LabelEncoder().fit_transform(Titanic['Sex'])
print(Titanic['Sex'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Sex, Length: 891, dtype: int32

# %%
#Correlating multiple numerical and categorical features
grid=sns.FacetGrid(Titanic,row='Sex',col='Survived',height=3, aspect=1.6)
grid.map(sns.barplot,'Sex','Age',alpha=.5,ci=None)
grid.add_legend()
# Out:
# C:\Users\BENSAN01\Anaconda3\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
Titanic[["Survived","Pclass","Age"]].groupby(["Survived"],as_index=True).mean()
# Out:
#             Pclass        Age
# Survived
# 0         1.531876  30.415100
# 1         0.950292  28.549778

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
    
plot_correlation_map(Titanic)

# %% [raw]
# a correlation matrix appeared called "HIT MAP". We observe that most of features do not correlate except maybe for 'Survived' and 'Sex', 'Pclass' and 'Fare'.

# %%
#Groupby
Titanic[["Survived","Pclass"]].groupby(["Survived"],as_index=True).mean()
# Out:
#             Pclass
# Survived
# 0         1.531876
# 1         0.950292

# %%
#Drop column Name
Titanic.drop("Name",axis=1)
# Out:
#      PassengerId Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 0            343       No       2    male  28.0      0      0      248740
# 1             76       No       3    male  25.0      0      0      348123
# 2            641       No       3    male  20.0      0      0      350050
# 3            568       No       3  female  29.0      0      4      349909
# 4            672       No       1    male  31.0      1      0  F.C. 12750
# ..           ...      ...     ...     ...   ...    ...    ...         ...
# 886           10      Yes       2  female  14.0      1      0      237736
# 887           61       No       3    male  22.0      0      0        2669
# 888          535       No       3  female  30.0      0      0      315084
# 889          102       No       3    male   NaN      0      0      349215
# 890          428      Yes       2  female  19.0      0      0      250655
#
#         Fare  Cabin Embarked
# 0    13.0000    NaN        S
# 1     7.6500  F G73        S
# 2     7.8542    NaN        S
# 3    21.0750    NaN        S
# 4    52.0000    B71        S
# ..       ...    ...      ...
# 886  30.0708    NaN        C
# 887   7.2292    NaN        C
# 888   8.6625    NaN        S
# 889   7.8958    NaN        S
# 890  26.0000    NaN        S
#
# [891 rows x 11 columns]

# %%
#KAHINA
                
Dict = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       1
# 1             76         0       2
# 2            641         0       2
# 3            568         0       2
# 4            672         0       0
# ..           ...       ...     ...
# 886           10         1       1
# 887           61         0       2
# 888          535         0       2
# 889          102         0       2
# 890          428         1       1
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.000000      1
# 887                              Sirayanian, Mr. Orsen    1  22.000000      0
# 888                                Cacic, Miss. Marija    0  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.000000      0
#
#      Parch      Ticket     Fare Embarked
# 0        0      248740  13.0000        S
# 1        0      348123   7.6500        S
# 2        0      350050   7.8542        S
# 3        4      349909  21.0750        S
# 4        0  F.C. 12750  52.0000        S
# ..     ...         ...      ...      ...
# 886      0      237736  30.0708        C
# 887      0        2669   7.2292        C
# 888      0      315084   8.6625        S
# 889      0      349215   7.8958        S
# 890      0      250655  26.0000        S
#
# [891 rows x 11 columns]

# %%
import pandas as pd
for Dict in Titanic:
    Titanic['Title'] = Titanic.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(Titanic['Title'], Titanic['Sex'])
# Out:
# Sex         0    1
# Title
# Capt        0    1
# Col         0    2
# Countess    1    0
# Don         0    1
# Dr          1    6
# Jonkheer    0    1
# Lady        1    0
# Major       0    2
# Master      0   40
# Miss      182    0
# Mlle        2    0
# Mme         1    0
# Mr          0  517
# Mrs       125    0
# Ms          1    0
# Rev         0    6
# Sir         0    1

# %%
Titanic["Title"].replace(Dict)
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       1
# 1             76         0       2
# 2            641         0       2
# 3            568         0       2
# 4            672         0       0
# ..           ...       ...     ...
# 886           10         1       1
# 887           61         0       2
# 888          535         0       2
# 889          102         0       2
# 890          428         1       1
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.000000      1
# 887                              Sirayanian, Mr. Orsen    1  22.000000      0
# 888                                Cacic, Miss. Marija    0  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.000000      0
#
#      Parch      Ticket     Fare Embarked Title
# 0        0      248740  13.0000        S    Mr
# 1        0      348123   7.6500        S    Mr
# 2        0      350050   7.8542        S    Mr
# 3        4      349909  21.0750        S   Mrs
# 4        0  F.C. 12750  52.0000        S    Mr
# ..     ...         ...      ...      ...   ...
# 886      0      237736  30.0708        C   Mrs
# 887      0        2669   7.2292        C    Mr
# 888      0      315084   8.6625        S  Miss
# 889      0      349215   7.8958        S    Mr
# 890      0      250655  26.0000        S  Miss
#
# [891 rows x 12 columns]
